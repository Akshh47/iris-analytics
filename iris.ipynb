# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns 
from  plotly.offline import iplot
import plotly as py 
import plotly.tools as tls 
 
# %matplotlib inline

# %%
np.random.randn(1000)
# Out:
# array([-1.20014323e+00,  2.01343342e+00, -4.06802696e-01, -4.68124036e-01,
#         4.76726528e-01,  9.59985159e-01,  1.32904164e+00, -9.64460261e-01,
#        -2.18320504e-01,  1.33493126e+00, -1.12009596e+00, -6.77290774e-01,
#         1.47530395e+00,  1.58025062e+00,  4.66613868e-01,  2.33912990e-01,
#         5.50709987e-01,  6.72001571e-01, -8.18334957e-01, -7.11736628e-01,
#         1.22386933e+00,  1.92714336e+00,  2.41724517e-01, -1.40568344e-01,
#         2.33344147e-01, -8.36132139e-01,  1.04575542e+00,  6.41948288e-01,
#         3.96174469e-01, -4.58218374e-01, -8.27564433e-01, -4.33998654e-01,
#        -1.18523184e+00, -5.72135863e-01, -7.00083037e-01, -2.22659792e-01,
#        -7.98393671e-01,  3.06028926e-01,  1.59309253e+00, -2.03534327e+00,
#         1.67177240e+00,  1.11717311e+00, -2.08283950e+00,  9.84553904e-01,
#        -2.84881988e-01,  1.29200577e-01, -1.07290567e+00, -6.00209340e-01,
# ...

# %%
df=pd.DataFrame(np.random.randn(1000),columns=['data'])

# %%
df.head()
# Out:
#        data
# 0 -0.047484
# 1  2.414490
# 2 -0.765017
# 3 -2.508041
# 4  0.046685

# %%
df.plot(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns

# %%
df =  pd.read_csv('https://gist.githubusercontent.com/curran/a08a1080b88344b0c8a7/raw/0e7a9b0a5d22642a06d3d5b9bcbad9890c8ee534/iris.csv')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.iloc[5:11]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa

# %%
df.iloc[5:11].plot(kind = 'bar',figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
df.shape
# Out:
# (150, 5)

# %%
df.iloc[5:11].plot(kind = 'barh',figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
df.iloc[5:11].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['sepal_length'].plot(kind = 'hist',figsize=(10,10))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.hist(figsize=(10,10),color = 'r',alpha=.5)
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
df.plot(kind = 'box',color = {'boxes':'b','whiskers':'r'})
# Out:
# <AxesSubplot:>

# %%
df.plot(kind = 'area',figsize=(10,10),alpha=.5)
# Out:
# <AxesSubplot:>

# %%
df.plot.scatter(x='sepal_length',y='petal_length')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.hexbin(x='sepal_length',y='petal_length')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df1=df.drop(columns = 'species').iloc[0]
df1.plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='0'>

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
import plotly as py

# %%
from  plotly.offline import iplot
import plotly as py

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
py.offline.init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
# ...

# %%
import cufflinks as cf

# %%
df.iplot(x = 'sepal_length' , y = 'sepal_width' , z = 'petal_length' , kind = 'scatter3d')
# Out:
# <div>                            <div id="735601b4-c1b8-4fa6-b107-ecc307386b5d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
